# %%
import torch
import numpy as np

# %%
torch.__version__
# Out:
# '2.10.0+cu130'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
print(torch.version.cuda)
# Out:
# 13.0

# %%
x = torch.tensor([1,2,3], device='cuda', dtype=torch.float32)
y = torch.tensor([1,2,3], device='cuda', dtype=torch.float32)
x
# Out:
# tensor([1., 2., 3.], device='cuda:0')

# %%
x+y
# Out:
# tensor([2., 4., 6.], device='cuda:0')

# %%
np_arr = np.array([1,2,3])

# %%
x.cpu().numpy()
# Out:
# array([1., 2., 3.], dtype=float32)

# %% [markdown]
# como le hice cuda se copio si no no se copia!

# %%
pt_tensor = torch.from_numpy(np_arr).to('cuda')
other = torch.tensor(np_arr)

# %%
np_arr[0] = 999

# %%
pt_tensor
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
# Out:
# tensor([1, 2, 3])
